# %%
people = {
    'first': ['Corey', 'Jane', 'John'], 
    'last': ['Schafer', 'Doe', 'Doe'], 
    'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
# Adding a new column
df['full_name'] = df['first'] + ' ' + df['last']
df
# Out:
#    first     last                    email      full_name
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe
# 2   John      Doe        JohnDoe@email.com       John Doe

# %%
df['number'] = [1, 2, 3]
df
# Out:
#    first     last                    email      full_name  number
# 0  Corey  Schafer  CoreyMSchafer@gmail.com  Corey Schafer       1
# 1   Jane      Doe        JaneDoe@email.com       Jane Doe       2
# 2   John      Doe        JohnDoe@email.com       John Doe       3

# %%
# to remove columns
df.drop(columns = ['first', 'last'], inplace = True)

# %%
df
# Out:
#                      email      full_name  number
# 0  CoreyMSchafer@gmail.com  Corey Schafer       1
# 1        JaneDoe@email.com       Jane Doe       2
# 2        JohnDoe@email.com       John Doe       3

# %%
df.drop(columns = 'number', inplace  =True)
df
# Out:
#                      email      full_name
# 0  CoreyMSchafer@gmail.com  Corey Schafer
# 1        JaneDoe@email.com       Jane Doe
# 2        JohnDoe@email.com       John Doe

# %%
# Now adding two new columns
df[['first', 'last']] = df['full_name'].str.split(' ', expand = True)
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe

# %%
# To add a mnew row
df.loc[len(df)] = {'first': 'pavan', 'last': 'kalyan'}
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN  pavan      NaN
# 4                      NaN            NaN  pavan   kalyan

# %%
df
# Out:
#                      email      full_name  first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer  Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe   Jane      Doe
# 2        JohnDoe@email.com       John Doe   John      Doe
# 3                      NaN            NaN  pavan      NaN
# 4                      NaN            NaN  pavan   kalyan

# %%
# adding anothe row using concat method
new_row = {'first' : 'vasanth'}
df = pd.concat([df, pd.DataFrame([new_row])], ignore_index = True)

# %%
df
# Out:
#                      email      full_name    first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer    Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe     Jane      Doe
# 2        JohnDoe@email.com       John Doe     John      Doe
# 3                      NaN            NaN    pavan      NaN
# 4                      NaN            NaN    pavan   kalyan
# 5                      NaN            NaN  vasanth      NaN

# %%
# to remove rows
df.drop(index = 4, inplace = True)
df
# Out:
#                      email      full_name    first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer    Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe     Jane      Doe
# 2        JohnDoe@email.com       John Doe     John      Doe
# 3                      NaN            NaN    pavan      NaN
# 5                      NaN            NaN  vasanth      NaN

# %%
filt = (df['first'] == 'pavan')
df.drop(index = df[filt].index, inplace = True)
df
# Out:
#                      email      full_name    first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer    Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe     Jane      Doe
# 2        JohnDoe@email.com       John Doe     John      Doe
# 5                      NaN            NaN  vasanth      NaN

# %%
df.drop(index = df[df['last'] == 'Doe'].index)
# Out:
#                      email      full_name    first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer    Corey  Schafer
# 5                      NaN            NaN  vasanth      NaN

# %%
df
# Out:
#                      email      full_name    first     last
# 0  CoreyMSchafer@gmail.com  Corey Schafer    Corey  Schafer
# 1        JaneDoe@email.com       Jane Doe     Jane      Doe
# 2        JohnDoe@email.com       John Doe     John      Doe
# 5                      NaN            NaN  vasanth      NaN
